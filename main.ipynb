# %%
import pandas as pd
import numpy as np

ndf = pd.read_csv("datasets/numerical/houses_data.csv")

ndf.head()
# Out:
#        Location  Year_Built  Price_USD  Bedrooms  Bathrooms  Square_Feet  \
# 0       Houston        1994  739971.84         6          1          NaN
# 1      New York        1941  579540.19         6          1       9173.0
# 2     San Diego        1963  944896.93         3          5       7738.0
# 3       Houston        1906  998953.18         7          3       7162.0
# 4  Philadelphia        1960  707713.12         7          5       4076.0
#
#    Street_Type  Price_per_Square_Foot
# 0      Highway                    150
# 1   Corner Lot                    200
# 2  Side Street                    180
# 3  Main Street                    150
# 4  Main Street                    120

# %%
ndf.isna().sum()
# Out:
# Location                   0
# Year_Built                 0
# Price_USD                  0
# Bedrooms                   0
# Bathrooms                  0
# Square_Feet              100
# Street_Type                0
# Price_per_Square_Foot      0
# dtype: int64

# %%
from importlib import reload
import utils.preprocessing as pre

pre = reload(pre) # this only a part of import statement related to ipynb files when importing custom files

# %%
ndf = pre.clean_data(ndf, ["Square_Feet"])
ndf.head()
# Out:
#        Location  Year_Built  Price_USD  Bedrooms  Bathrooms  Square_Feet  \
# 0       Houston        1994  739971.84         6          1      5199.27
# 1      New York        1941  579540.19         6          1      9173.00
# 2     San Diego        1963  944896.93         3          5      7738.00
# 3       Houston        1906  998953.18         7          3      7162.00
# 4  Philadelphia        1960  707713.12         7          5      4076.00
#
#    Street_Type  Price_per_Square_Foot
# 0      Highway                    150
# 1   Corner Lot                    200
# 2  Side Street                    180
# 3  Main Street                    150
# 4  Main Street                    120

# %%
ndf = pre.encode_text_to_numbers(ndf, ["Location", "Street_Type"])
ndf.head()
# Out:
#    Location  Year_Built  Price_USD  Bedrooms  Bathrooms  Square_Feet  \
# 0         1        1994  739971.84         6          1      5199.27
# 1         3        1941  579540.19         6          1      9173.00
# 2         7        1963  944896.93         3          5      7738.00
# 3         1        1906  998953.18         7          3      7162.00
# 4         4        1960  707713.12         7          5      4076.00
#
#    Street_Type  Price_per_Square_Foot
# 0            1                    150
# 1            0                    200
# 2            4                    180
# 3            2                    150
# 4            2                    120

# %%
import os

new_csv_path = "./datasets/numerical/houses_data(cleaned).csv"

if not os.path.exists(new_csv_path):
    ndf.to_csv(new_csv_path, index=False) # create new CSV file which holds cleaned data

# %%
train_image_df = pd.read_csv("./datasets/image/images_dataset/Train_set/train_dataset.csv")
test_image_df = pd.read_csv("./datasets/image/images_dataset/Test_set/test_dataset.csv")
# Out:
# (1672, 12288)

# %%
X_image_train, X_image_test = train_image_df.iloc[:, 1:], test_image_df.iloc[:, 1:]
Y_image_train, Y_image_test = train_image_df.iloc[:, 0], test_image_df.iloc[:, 0]

print(X_image_train.shape)
print(X_image_test.shape)
# Out:
# (1672, 12288)
# (405, 12288)

# %%
from sklearn.decomposition import PCA

# Normalize the data
X_image_train /= 255.0
X_image_test /= 255.0

# Apply PCA for dimensionality reduction
pca = PCA(n_components=1672) # make the dataframe have at most 1672 features

X_image_train = pca.fit_transform(X_image_train)

X_image_test = pca.transform(X_image_test)

# %%
from sklearn.linear_model import LogisticRegression

LGRM = LogisticRegression(random_state=42, max_iter=1000)

LGRM.fit(X_image_train, Y_image_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
LGRM_Y_pred = LGRM.predict(X_image_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 3  
KNNM = KNeighborsClassifier(n_neighbors=k, metric = 'minkowski', p = 2) #since metric='minkowski' and p=2, the Euclidean distance is used for measuring the distance between points.

KNNM.fit(X_image_train, Y_image_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
KNN_Y_pred = KNNM.predict(X_image_test)

# %%
# Out:
# (1672,)
